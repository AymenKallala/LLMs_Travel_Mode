# %%
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
from data import load,load_for_correction
from ChatGPT import OpenAI_Tweet_Analyzer,predict_dataset,verify_dataset

# %load_ext autoreload
# %autoreload 2

# %%
DATA_PATH = 'results/0_1999_In_Context_Learning.xlsx - Sheet1.csv'
dataset,correction = load_for_correction(DATA_PATH,start=0,end=20)

# %%
correction.head()
# Out:
#   Travel_mode_verification Satisfaction_verification
# 0                     True                      True
# 1                     True                      True
# 2                     True                      True
# 3                     True                      True
# 4                     True                      True

# %%
dataset.head()
# Out:
#                                                tweet Travel Mode  \
# 0  yeah it always be some old caribbean dude head...       train
# 1  i was out of ny for too long taking the train ...       train
# 2  i am not in the mood to be stared at because i...       train
# 3  imagine if he knew how sent you on the subway ...      subway
# 4  remember when you could not get cell service i...      subway
#
#    Satisfaction                                             Reason
# 0  dissatisfied  uncomfortable interaction with a fellow passenger
# 1  dissatisfied                                           nauseous
# 2  dissatisfied                         being judged and stared at
# 3       neutral                                                NaN
# 4  dissatisfied                         could not get cell service

# %%
model = OpenAI_Tweet_Analyzer(model_name="gpt-3.5-turbo-1106",max_tokens = 100,temperature=0.7,prompt_technique="self_verification")

# %%
output = verify_dataset(model,dataset)
# Out:
# ...
# 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]

# %%
def correcter_rate(pred,groundtruth):
    gt = groundtruth[["Travel_mode_verification","Satisfaction_verification"]]
    pred = pred[["Travel_mode_verification","Satisfaction_verification"]]

    correct_pred = sum(pred["Travel_mode_verification"]==gt["Travel_mode_verification"]) + sum(pred["Satisfaction_verification"]==gt["Satisfaction_verification"])
    total = len(gt) * 2

    return correct_pred/total

# %%
print(correcter_rate(output,correction))
# Out:
# 0.85

# %%
correction== output
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/tmp/ipykernel_360389/2720093764.py in ?()
# ----> 1 correction== output
#
# /opt/conda/envs/llm/lib/python3.12/site-packages/pandas/core/ops/common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# /opt/conda/envs/llm/lib/python3.12/site-packages/pandas/core/arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# /opt/conda/envs/llm/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, other, op)
#    7625     def _cmp_method(self, other, op):
#    7626         axis: Literal[1] = 1  # only relevant for Series other case
#    7627
# ...

# %%
out
# Out:
#     Travel_mode_verification  Satisfaction_verification  Reason_verification
# 0                       True                      False                 True
# 1                       True                       True                 True
# 2                       True                       True                 True
# 3                       True                      False                False
# 4                       True                       True                 True
# 5                       True                       True                 True
# 6                       True                       True                 True
# 7                       True                       True                 True
# 8                      False                       True                 True
# 9                      False                       True                 True
# 10                     False                       True                 True
# ...

# %%
import json

string = str({    "Travel_mode_verification" : True,    "Satisfaction_verification" : True,    "Reason_verification": True,})

at = json.loads(string)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /home/aymenkallala/LLMs_Travel_Mode/self_verification.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bgcp_instance_3/home/aymenkallala/LLMs_Travel_Mode/self_verification.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import json
#       <a href='vscode-notebook-cell://ssh-remote%2Bgcp_instance_3/home/aymenkallala/LLMs_Travel_Mode/self_verification.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> string = str({    "Travel_mode_verification" : True,    "Satisfaction_verification" : True,    "Reason_verification": True,})
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgcp_instance_3/home/aymenkallala/LLMs_Travel_Mode/self_verification.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> at = json.loads(string)
#
# ...

# %%
output_df
# Out:
#     Travel_mode_verification  Satisfaction_verification  Reason_verification
# 0                       True                       True                 True
# 1                       True                       True                 True
# 2                       True                       True                 True
# 3                       True                       True                False
# 4                       True                       True                 True
# 5                       True                       True                 True
# 6                       True                       True                 True
# 7                      False                       True                 True
# 8                      False                       True                 True
# 9                      False                       True                 True
# 10                     False                       True                 True
# ...

# %%
correction
# Out:
#    Travel Mode Correction Groundtruth Satisfaction Correction Groundtruth
# 0                                True                                True
# 1                                True                                True
# 2                                True                                True
# 3                                True                                True
# 4                                True                                True
# 5                                True                                True
# 6                               False                                True
# 7                                True                                True
# 8                               False                                True
# 9                               False                                True
# 10                               True                                True
# 11                               True                                True
# ...
