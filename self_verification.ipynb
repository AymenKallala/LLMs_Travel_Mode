# %%
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
from data import load

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ANALOG_PATH = 'results/0_1999_Analogical_Prompting.xlsx'
COT_PATH = 'results/0_1999_In_Context_Learning.xlsx'
DATA_PATH = 'results/0_1999_In_Context_Learning.xlsx'

dataset = load(DATA_PATH,start=0,end =20,verification=True)

# %%
dataset
# Out:
#                                                 tweet Travel Mode  \
# 0   yeah it always be some old caribbean dude head...       train
# 1   i was out of ny for too long taking the train ...       train
# 2   i am not in the mood to be stared at because i...       train
# 3   imagine if he knew how sent you on the subway ...      subway
# 4   remember when you could not get cell service i...      subway
# 5   we almost did not make it out the subway and t...      subway
# 6   commute felt like the old days today. went to ...      subway
# 7   "it is not a short tunnel." i guarantee you he...      subway
# 8   just noticed the mta (?) installed stee bollar...         mta
# 9   too bad the mta has done nothing to increase s...         mta
# 10  crooked mta! governor cuomo time to get rid of...         NaN
# 11  i am at mta subway 63rd dr and rego park (m an...      subway
# 12  can you tell the 96st station to move one of t...       train
# 13  great, i am stuck in the train waiting for it ...       train
# 14  a drunk man just pulled down his mask and shov...         mta
# 15  the new normal 7 express to flushing main st a...      subway
# 16  thank you bus driver of 6263, needs to give hi...         bus
# 17  sometimes you really do got to change subway c...      subway
# 18  was that black city edition jersey with the su...      subway
# 19  walking 6 blocks to my apartment instead of ta...     walking
#
#     Satisfaction                                             Reason
# 0   dissatisfied  uncomfortable interaction with a fellow passenger
# 1   dissatisfied                                           nauseous
# 2   dissatisfied                         being judged and stared at
# 3        neutral                                                NaN
# 4   dissatisfied                         could not get cell service
# 5   dissatisfied                                   doors shut on me
# 6   dissatisfied               multiple subway lines out of service
# 7        neutral                                 not a short tunnel
# 8      satisfied  installed steel bollards next to the new elevator
# 9   dissatisfied  lack of service on 4th ave and the need to rec...
# 10  dissatisfied  crooked mta and governor cuomo time to get rid...
# 11       neutral                                                NaN
# 12       neutral          request for train to move to clear tracks
# 13  dissatisfied            waiting for it to move, need a bathroom
# 14  dissatisfied            drunk man eating ice cream with fingers
# 15           NaN                                                NaN
# 16     satisfied            Bus driver enforced mask wearing policy
# 17       neutral                                 vibes are just off
# 18       neutral                      official announcement unclear
# 19       neutral          chose to walk instead of taking the train

# %%
from ChatGPT.model import OpenAI_Tweet_Analyzer,predict_dataset,verify_dataset

model = OpenAI_Tweet_Analyzer(model_name="gpt-3.5-turbo-1106",max_tokens = 100,temperature=0.7,prompt_technique="self_verification")

# %%
output_df = verify_dataset(model,dataset)
# Out:
# 100%|██████████| 20/20 [00:21<00:00,  1.07s/it]
# An error occured with json formatting of the LLM output
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/tmp/ipykernel_31139/3153043340.py in ?()
# ----> 1 output_df = verify_dataset(model,dataset)
#
# ~/LLMs_Travel_Mode/ChatGPT/model.py in ?(analyzer, dataset, sleep)
#      82         output_dict[global_id] = answer
#      83         if sleep:
#      84             time.sleep(20)
#      85
# ---> 86     return process_output(output_dict, technique=analyzer.prompt_technique)
#
# ~/LLMs_Travel_Mode/ChatGPT/utils.py in ?(output_dict, technique)
#     269             ]
#     270         ]
#     271
#     272     if technique == "self_verification":
# --> 273         output_df = pd.DataFrame.from_dict(
#     274             output_dict, orient="index"
#     275         )
#     276         output_df["Travel_mode_verification"] = output_df["Travel_mode_verification"].apply(lambda x: tm_verification(x))
#
# /opt/conda/envs/llm/lib/python3.12/site-packages/pandas/core/frame.py in ?(cls, data, orient, dtype, columns)
#    1793         if orient == "index":
#    1794             if len(data) > 0:
#    1795                 # TODO speed up Series case
#    1796                 if isinstance(next(iter(data.values())), (Series, dict)):
# -> 1797                     data = _from_nested_dict(data)
#    1798                 else:
#    1799                     index = list(data.keys())
#    1800                     # error: Incompatible types in assignment (expression has type
#
# /opt/conda/envs/llm/lib/python3.12/site-packages/pandas/core/frame.py in ?(data)
#   12284 def _from_nested_dict(data) -> collections.defaultdict:
#   12285     new_data: collections.defaultdict = collections.defaultdict(dict)
#   12286     for index, s in data.items():
# > 12287         for col, v in s.items():
#   12288             new_data[col][index] = v
#   12289     return new_data
#
# AttributeError: 'str' object has no attribute 'items'

# %%
output_df
# Out:
#    Travel_mode_verification Satisfaction_verification Reason_satisfaction
# 0                      True                     False                True
# 1                      True                      True                True
# 2                      True                      True                True
# 3                      True                     False                True
# 4                      True                     False                True
# 5                      True                     False                True
# 6                      True                      True                True
# 7                     False                     False                True
# 8                     False                     False                True
# 9                     False                     False                True
# 10                    False                     False                True
# 11                     True                     False                True
# 12                     True                     False                True
# 13                     True                      True                True
# 14                     True                     False                True
# 15                     True                      True                True
# 16                     True                      True                True
# 17                     True                     False                True
# 18                    False                     False               False
# 19                     True                     False                True
